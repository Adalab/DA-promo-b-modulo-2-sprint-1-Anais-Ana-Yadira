# %%
import pandas as pd

# %%
df = pd.read_csv('attacks.csv')
df
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 4              4    2018.06.04  2018.0      Provoked     MEXICO
# ...          ...           ...     ...           ...        ...
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# ...

# %% [markdown]
# ¿Cuántas filas y columnas tiene el DataFrame?

# %%
shape_df= df.shape
print(f'El DataFrame tiene {shape_df[0]} filas y {shape_df[1]} columnas')
# Out:
# El DataFrame tiene 6114 filas y 22 columnas

# %% [markdown]
# Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.

# %%
print('Las primeras 5 filas son:')
df.head()
# Out:
# Las primeras 5 filas son:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
print('Las últimas 5 filas son:')
df.tail()
# Out:
# Las últimas 5 filas son:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 6109    New South Wales    Georges Head, off Port Jackson
# 6110     South Carolina                    Off Charleston
# 6111  Western Australia  Hamelin Harbour, at Faure Island
# 6112                NaN                               NaN
# 6113                NaN                               NaN
#
#                              Activity                             Name Sex   \
# 6109                              NaN                             boat  NaN
# ...

# %% [markdown]
# Mostrad 2 filas al azar del DataFrame.

# %%
print('Mostramos dos filas al azar:')
df.sample(2)
# Out:
# Mostramos dos filas al azar:
#       Unnamed: 0   Case Number    Year        Type Country        Area  \
# 83            83  2017.09.16.a  2017.0  Unprovoked     USA     Florida
# 1773        1780  2003.04.23.b  2003.0  Unprovoked  BRAZIL  Pernambuco
#
#                                                Location Activity  \
# 83                          Ponce Inlet, Volusia County  Surfing
# 1773  Pau Amarelo Beach, Paulista District (17 km fr...  Surfing
#
#                                 Name Sex   ...    Species   \
# 83                              male    M  ...         NaN
# 1773  Tiago Augusto da Silva Machado    M  ...  Bull shark
#
#                                  Investigator or Source  \
# 83                          Orlando Sentinel, 9/16/2017
# 1773  P. M. Lopes, GSAF; N. Souza da Silva; JC, 4/24...
#
#                            pdf  \
# 83    2017.09.16.a-Volusia.pdf
# 1773  2003.04.23.b-Machado.pdf
#
#                                            href formula  \
# ...

# %% [markdown]
# ¿Cuál es el nombre de las columnas del DataFrame?

# %%
print('Los nombres de las columnas son:')
columnas_df = df.columns
columnas_df
# Out:
# Los nombres de las columnas son:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.

# %%
print('Las principales estadísticas de variables numéricas son: ')
df.describe()
# Out:
# Las principales estadísticas de variables numéricas son:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %%
print('Las principales estadísticas de variables categóricas son: ')
df.describe(include='object')
# Out:
# Las principales estadísticas de variables categóricas son:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# ...

# %% [markdown]
# ¿Cuál es el porcentaje de valores nulos en cada columna?

# %%
nul = df.isnull().sum()
nul
# Out:
# Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64

# %%
nul.size
# Out:
# 22

# %%
lista = []
for i in range(nul.size):
    
    
    porcentaje = nul[i]*100/6114
    lista.append(round(porcentaje, 2))

    
print(lista)
# Out:
# [0.0, 0.02, 0.0, 0.07, 0.65, 6.67, 7.98, 8.36, 3.27, 9.0, 43.6, 52.01, 44.24, 0.26, 0.0, 0.02, 0.0, 0.0, 0.0, 0.0, 99.98, 99.97]

# %% [markdown]
# Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.

# %%
valores_unicos = {}
for i in columnas_df:

    valores_unicos.update({i:df[i].unique()})

valores_unicos
# Out:
# {'Unnamed: 0': array([   0,    1,    2, ..., 6129, 6130, 6131]),
#  'Case Number': array(['2018.06.25', '2018.06.18', '2018.06.09', ..., '1803.03.00',
#         '1802.04.13.R', '1801.12.18.R'], dtype=object),
#  'Year': array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#         2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#         2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993.,
#         1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986., 1985.,
#         1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975.,
#         1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966., 1965.,
#         1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#         1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1848.,
#         1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939.,
#         1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930.,
# ...

# %% [markdown]
# Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.

# %%
columnas_nuevas = {col :  col.lower().replace(' ','_') for col in df.columns}
columnas_nuevas
# Out:
# {'Unnamed: 0': 'unnamed:_0',
#  'Case Number': 'case_number',
#  'Year': 'year',
#  'Type': 'type',
#  'Country': 'country',
#  'Area': 'area',
#  'Location': 'location',
#  'Activity': 'activity',
#  'Name': 'name',
#  'Sex ': 'sex_',
#  'Age': 'age',
#  'Time': 'time',
#  'Species ': 'species_',
#  'Investigator or Source': 'investigator_or_source',
#  'pdf': 'pdf',
#  'href formula': 'href_formula',
#  'href': 'href',
#  'Case Number.1': 'case_number.1',
#  'Case Number.2': 'case_number.2',
#  'original order': 'original_order',
#  'Unnamed: 22': 'unnamed:_22',
#  'Unnamed: 23': 'unnamed:_23'}

# %%
df.rename(columns = columnas_nuevas, inplace = True)
df.columns
# Out:
# Index(['unnamed:_0', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number.1', 'case_number.2', 'original_order', 'unnamed:_22',
#        'unnamed:_23'],
#       dtype='object')

# %% [markdown]
# Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.

# %%
df_eliminar = df.drop(["unnamed:_22", "unnamed:_23", "case_number.1", "case_number.2", "original_order", "investigator_or_source", "pdf", "href_formula"], axis = 1)

# %%
df_eliminar.head()
# Out:
#    unnamed:_0 case_number    year        type    country             area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...

# %% [markdown]
# Establece la columna Case Number como índice del DataFrame.

# %%
df_eliminar.set_index(["case_number"], inplace = True)

# %%
df_eliminar
# Out:
#               unnamed:_0    year          type    country               area  \
# case_number
# 2018.06.25             0  2018.0       Boating        USA         California
# 2018.06.18             1  2018.0    Unprovoked        USA            Georgia
# 2018.06.09             2  2018.0       Invalid        USA             Hawaii
# 2018.06.08             3  2018.0    Unprovoked  AUSTRALIA    New South Wales
# 2018.06.04             4  2018.0      Provoked     MEXICO             Colima
# ...                  ...     ...           ...        ...                ...
# 1804.02.26.R        6127  1804.0          Boat  AUSTRALIA    New South Wales
# 1803.05.17          6128  1803.0  Sea Disaster        USA     South Carolina
# 1803.03.00          6129  1803.0    Unprovoked  AUSTRALIA  Western Australia
# 1802.04.13.R        6130  1802.0    Unprovoked      INDIA                NaN
# 1801.12.18.R        6131  1801.0      Provoked        NaN                NaN
#
# ...

# %%
df_eliminar.columns
# Out:
# Index(['unnamed:_0', 'year', 'type', 'country', 'area', 'location', 'activity',
#        'name', 'sex_', 'age', 'time', 'species_', 'href'],
#       dtype='object')

# %% [markdown]
# Guarda el csv que no tiene esas columnas para seguir usándolo mañana.

# %%
df_eliminar.to_csv("attack_pair.csv")

# %%
df = pd.read_csv('attack_pair.csv')
df.head()
# Out:
#   case_number  unnamed:_0    year        type    country             area  \
# 0  2018.06.25           0  2018.0     Boating        USA       California
# 1  2018.06.18           1  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09           2  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08           3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04           4  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...
