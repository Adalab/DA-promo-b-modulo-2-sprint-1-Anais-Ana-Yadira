# %%
import pandas as pd
import numpy as np

# %% [markdown]
# EJERCICIO 1: Cargad el csv que guardasteis ayer.
#
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio. En las próximas sesiones lo iremos limpiando. Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame.
#
# Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios.
#
# df.dropna(inplace = True)
#
# ¿Cuántas filas se han eliminado con esta línea de código?

# %%
df = pd.read_csv("attack_pair.csv")

# %%
df1 = df.shape
df1
# Out:
# (6114, 14)

# %%
df.head()
# Out:
#   case_number  unnamed:_0    year        type    country             area  \
# 0  2018.06.25           0  2018.0     Boating        USA       California
# 1  2018.06.18           1  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09           2  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08           3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04           4  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6114 entries, 0 to 6113
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  6113 non-null   object
#  1   unnamed:_0   6114 non-null   int64
#  2   year         6114 non-null   float64
#  3   type         6110 non-null   object
#  4   country      6074 non-null   object
#  5   area         5706 non-null   object
#  6   location     5626 non-null   object
#  7   activity     5603 non-null   object
#  8   name         5914 non-null   object
#  9   sex_         5564 non-null   object
#  10  age          3448 non-null   object
#  11  time         2934 non-null   object
#  12  species_     3409 non-null   object
#  13  href         6114 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 668.8+ KB

# %%
df.dropna(inplace=True)

# %%
df2= df.shape
df2
# Out:
# (1502, 14)

# %%
filas_eliminadas= df1[0]-df2[0]
print (f"la cantidad de filas con contenido null que se han eliminado son: {filas_eliminadas}")
# Out:
# la cantidad de filas con contenido null que se han eliminado son: 4612

# %%
df.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %%
df.head()
# Out:
#      case_number  unnamed:_0    year        type    country        area  \
# 0     2018.06.25           0  2018.0     Boating        USA  California
# 6   2018.06.03.a           6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a          13  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# ...

# %% [markdown]
# EJERCICIO 2: ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
df_USA= df[df["country"]=="USA"]
df_USA
# Out:
#        case_number  unnamed:_0    year        type country           area  \
# 0       2018.06.25           0  2018.0     Boating     USA     California
# 8     2018.05.26.b           8  2018.0  Unprovoked     USA        Florida
# 35      2018.03.31          35  2018.0  Unprovoked     USA         Hawaii
# 53      2017.12.31          53  2017.0  Unprovoked     USA         Hawaii
# 60      2017.11.24          60  2017.0  Unprovoked     USA     California
# ...            ...         ...     ...         ...     ...            ...
# 4731    1941.06.15        4743  1941.0    Provoked     USA       New York
# 4734    1941.03.09        4746  1941.0    Provoked     USA     California
# 4862    1936.07.25        4874  1936.0  Unprovoked     USA  Massachusetts
# 5136    1926.07.08        5148  1926.0  Unprovoked     USA     California
# 5297    1916.07.01        5311  1916.0  Unprovoked     USA     New Jersey
#
#                                                location  \
# ...

# %%
df_ataques_usa = df_USA.shape[0]
print(f"La cantidad de ataques que se han producido en USA han sido: {df_ataques_usa}")
# Out:
# La cantidad de ataques que se han producido en USA han sido: 719

# %% [markdown]
# EJERCICIO 3: ¿Y en España?
# - 3.1 ¿En qué regiones se han producido los ataques?
# - 3.2 ¿Cuántos ataques se han producido en cada área?

# %%
df_spain= df[df["country"]=="SPAIN"]
df_ataques_spain = df_spain.shape[0]
print(f"La cantidad de ataques que se han producido en Spain han sido: {df_ataques_spain}")
# Out:
# La cantidad de ataques que se han producido en Spain han sido: 5

# %%
regiones_spain = df_spain["area"].unique()
print(f"Las regiones dónde han habido ataques son: {regiones_spain}")
# Out:
# Las regiones dónde han habido ataques son: ['Castellón' 'Alicante Province' 'Alicante' 'Grand Canary Island'
#  'Costa Blanca']

# %%
num_ataques= {}

for i in regiones_spain:
    area = df[df["area"]==i]
    ataques= area.shape[0]
    num_ataques.update({i:ataques})

pd.Series(num_ataques)
# Out:
# Castellón              1
# Alicante Province      1
# Alicante               1
# Grand Canary Island    1
# Costa Blanca           1
# dtype: int64

# %% [markdown]
# EJERCICIO 4: Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos. 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin(). Hacedlo con ambas herramientas.
# - 4.1 ¿Cuántos ataques se han producido en cada país?
# - 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?
# - 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?
# - 4.4 ¿Y después del 2000?

# %%
df_aus_usa= df[df["country"].isin(["AUSTRALIA", "USA"])]
df_aus_usa
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 0       2018.06.25           0  2018.0     Boating        USA
# 8     2018.05.26.b           8  2018.0  Unprovoked        USA
# 10      2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21    2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35      2018.03.31          35  2018.0  Unprovoked        USA
# ...            ...         ...     ...         ...        ...
# 5359    1912.01.26        5375  1912.0  Unprovoked  AUSTRALIA
# 5481    1905.03.26        5498  1905.0  Unprovoked  AUSTRALIA
# 5631    1894.11.28        5648  1894.0  Unprovoked  AUSTRALIA
# 5667    1892.03.02        5684  1892.0    Provoked  AUSTRALIA
# 5797    1880.11.25        5814  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 0            California                     Oceanside, San Diego County
# 8               Florida                    Cocoa Beach, Brevard  County
# ...

# %%
df_aus_usa1= df[(df["country"]== "AUSTRALIA") | (df["country"]== "USA")]
df_aus_usa1
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 0       2018.06.25           0  2018.0     Boating        USA
# 8     2018.05.26.b           8  2018.0  Unprovoked        USA
# 10      2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21    2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35      2018.03.31          35  2018.0  Unprovoked        USA
# ...            ...         ...     ...         ...        ...
# 5359    1912.01.26        5375  1912.0  Unprovoked  AUSTRALIA
# 5481    1905.03.26        5498  1905.0  Unprovoked  AUSTRALIA
# 5631    1894.11.28        5648  1894.0  Unprovoked  AUSTRALIA
# 5667    1892.03.02        5684  1892.0    Provoked  AUSTRALIA
# 5797    1880.11.25        5814  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 0            California                     Oceanside, San Diego County
# 8               Florida                    Cocoa Beach, Brevard  County
# ...

# %% [markdown]
# EJERCICIO 5: Extraed unicamente los ataques a mujeres.

# %%
df_mujeres= df[(df["sex_"]== "F")]
df_mujeres
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 40      2018.02.23          40  2018.0  Unprovoked     AUSTRALIA
# 53      2017.12.31          53  2017.0  Unprovoked           USA
# 71      2017.10.22          71  2017.0  Unprovoked     AUSTRALIA
# 75      2017.10.05          75  2017.0  Unprovoked           USA
# ...            ...         ...     ...         ...           ...
# 4151    1958.04.05        4163  1958.0  Unprovoked  SOUTH AFRICA
# 4170    1957.12.30        4182  1957.0  Unprovoked  SOUTH AFRICA
# 4678    1942.12.26        4690  1942.0  Unprovoked     AUSTRALIA
# 4706    1942.01.04        4718  1942.0  Unprovoked     AUSTRALIA
# 4913  1934.12.31.b        4925  1934.0  Unprovoked     AUSTRALIA
#
#                  area                                           location  \
# 0          California                        Oceanside, San Diego County
# ...

# %% [markdown]
# EJERCICIO 6: ¿Cuántas mujeres fueron atacadas en España?

# %%
df_mujeres_spain= df[(df["sex_"]== "F") & (df["country"]== "SPAIN")]
df_mujeres_spain

print(f'La cantidad de mujeres atacadas en España es: {df_mujeres_spain.shape[0]}')
# Out:
# La cantidad de mujeres atacadas en España es: 1

# %% [markdown]
# EJERCICIO 7: Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

# %%
df_years= df[df["year"].isin([2000, 1997, 2006])]
df_years
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 1407    2006.12.18        1412  2006.0  Unprovoked     AUSTRALIA
# 1408    2006.12.11        1413  2006.0  Unprovoked   NEW ZEALAND
# 1409    2006.12.10        1414  2006.0  Unprovoked           USA
# 1410    2006.12.06        1415  2006.0    Provoked  SOUTH AFRICA
# 1411    2006.12.02        1416  2006.0  Unprovoked     AUSTRALIA
# ...            ...         ...     ...         ...           ...
# 2246  1997.05.31.b        2253  1997.0  Unprovoked           USA
# 2247  1997.05.31.a        2254  1997.0  Unprovoked           USA
# 2252  1997.02.28.a        2259  1997.0  Unprovoked     AUSTRALIA
# 2256    1997.01.25        2263  1997.0  Unprovoked     AUSTRALIA
# 2257    1997.01.20        2264  1997.0  Unprovoked     AUSTRALIA
#
#                    area                              location       activity  \
# 1407           Victoria                Winki Pop, Bells Beach        Surfing
# ...

# %% [markdown]
# EJERCICIO 8: Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir en algo difícil. En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
df['species_'].unique()
# Out:
# array(['White shark', 'Tiger shark', "Bull shark, 6'", 'Grey reef shark',
#        'Invalid incident', '3 m shark', 'White shark, 2.5 m',
#        "Tiger shark, 12'", 'Wobbegong shark', '3.5 m shark',
#        '1.8 m shark', 'Juvenile white shark,  2.7 to 3.2 m',
#        'Bull shark, 2 m', 'small shark', 'White shark, 4.6 m',
#        '2 m shark', 'Wobbegong shark, 1 m', 'White shark, 4.5 m',
#        'Tiger shark, 8 to 10 feet', "8' shark", 'Questionable',
#        "5' to 6' shark", 'White shark, 3 to 3.5m ', 'White shark, 3 m',
#        'Shark involvement questionable', "White shark, 5' to 7'",
#        'Possibly a juvenile blacktip shark', "4' shark", 'A small shark',
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        "Bull shark, 4' to 5'", 'White shark, 4 m',
#        'Shark involvement highly doubtful', "Bull shark, 5' to 7'",
#        'Bull shark, 4 m', 'Bull shark, 1 m',
#        'Shark involvement not confirmed', 'Wobbegong shark, 2m',
# ...

# %%
# Solución con patrón regex

patron = '([Ww]hite\s[Ss]hark)'
df_tiburon_blanco = df[df["species_"].str.contains(patron, regex=True)]
df_tiburon_blanco.sample(10)
# Out:
# /tmp/ipykernel_15218/474050869.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_tiburon_blanco = df[df["species_"].str.contains(patron, regex=True)]
#        case_number  unnamed:_0    year        type      country  \
# 270     2016.05.31         271  2016.0  Unprovoked    AUSTRALIA
# 3437    1968.12.25        3447  1968.0  Unprovoked  NEW ZEALAND
# 3239    1974.09.28        3249  1974.0  Unprovoked          USA
# 40      2018.02.23          40  2018.0  Unprovoked    AUSTRALIA
# 2566    1991.12.04        2573  1991.0  Unprovoked          USA
# 3245    1974.09.00        3255  1974.0  Unprovoked          USA
# 3688  1964.02.05.a        3699  1964.0  Unprovoked  NEW ZEALAND
# 1218  2008.07.30.R        1223  2008.0  Unprovoked    AUSTRALIA
# 2207    1997.11.09        2214  1997.0  Unprovoked    AUSTRALIA
# 394     2015.07.03         395  2015.0  Unprovoked    AUSTRALIA
#
# ...

# %%
# Solución usando 'case' = False

df_tiburon_blanco= df[df["species_"].str.contains("white shark", case=False)]
df_tiburon_blanco
# Out:
#      case_number  unnamed:_0    year        type       country  \
# 0     2018.06.25           0  2018.0     Boating           USA
# 24    2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# 34    2018.04.03          34  2018.0  Unprovoked  SOUTH AFRICA
# 40    2018.02.23          40  2018.0  Unprovoked     AUSTRALIA
# 60    2017.11.24          60  2017.0  Unprovoked           USA
# ...          ...         ...     ...         ...           ...
# 5212  1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216  1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218  1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5297  1916.07.01        5311  1916.0  Unprovoked           USA
# 5528  1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                            location  \
# 0                California         Oceanside, San Diego County
# 24    Western Cape Province      Robberg Beach, Plettenberg Bay
# ...

# %% [markdown]
# EJERCICIO 9: Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

# %%
# Solución usando patrón regex 

patron = '([Ww]hite\s[Ss]hark|[Tt]iger\s[Ss]hark)'
df_tiburon_blanco_tigre = df[df["species_"].str.contains(patron, regex=True)]
df_tiburon_blanco_tigre
# Out:
# /tmp/ipykernel_15218/2848705324.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   df_tiburon_blanco_tigre = df[df["species_"].str.contains(patron, regex=True)]
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 6     2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 18    2018.04.28.b          18  2018.0  Unprovoked    COSTA RICA
# 23      2018.04.23          23  2018.0  Unprovoked      MALDIVES
# 24      2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# ...            ...         ...     ...         ...           ...
# 5212    1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216    1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218    1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5297    1916.07.01        5311  1916.0  Unprovoked           USA
# ...

# %%
# Solución usando 'case'= False

df_tiburon_blanco_tigre= df[(df["species_"].str.contains("white shark", case= False)) | (df["species_"].str.contains("tiger", case=False))]
df_tiburon_blanco_tigre
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 6     2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 18    2018.04.28.b          18  2018.0  Unprovoked    COSTA RICA
# 23      2018.04.23          23  2018.0  Unprovoked      MALDIVES
# 24      2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# ...            ...         ...     ...         ...           ...
# 5212    1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216    1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218    1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5297    1916.07.01        5311  1916.0  Unprovoked           USA
# 5528    1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                        location  \
# 0                California     Oceanside, San Diego County
# 6                Pernambuco           Piedade Beach, Recife
# ...

# %% [markdown]
# EJERCICIO 10: Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
df['siglo'] = np.where(df['year'] < 2000, 'siglo-XX', 'siglo-XXI')

# %%
df.head(5)
# Out:
#      case_number  unnamed:_0    year        type    country        area  \
# 0     2018.06.25           0  2018.0     Boating        USA  California
# 6   2018.06.03.a           6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a          13  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# ...

# %% [markdown]
# EJERCICIO 11: Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.

# %%
df.to_csv('attack_filtrado.csv')
