# %% [markdown]
# En el ejercicio de ayer estuvimos viendo el groupby y pudimos observar que los datos estaban un poco sucios... 😭. En los ejercicios de hoy pondremos en práctica los apply, y nos crearemos algunas funciones que nos van a permitir limpiar un poco los datos, para que podamos extraer conclusiones de una forma más sencilla.

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('attack_merge.csv')
df.head(20)
# Out:
#     unnamed:_0_x   case_number    year          type            country  \
# 0           6132    1800.00.00  1800.0    Unprovoked         SEYCHELLES
# 1           6133  1797.05.28.R  1797.0    Unprovoked                NaN
# 2           6134    1792.09.12  1792.0      Provoked            ENGLAND
# 3           6135    1791.00.00  1791.0    Unprovoked          AUSTRALIA
# 4           6136    1788.05.10  1788.0          Boat          AUSTRALIA
# 5           6137    1787.07.05  1787.0    Unprovoked                NaN
# 6           6138  1786.08.10.R  1786.0    Unprovoked           BARBADOS
# 7           6139  1785.09.26.R  1785.0    Unprovoked            ENGLAND
# 8           6140    1784.12.12  1784.0    Unprovoked            JAMAICA
# 9           6141    1783.03.02  1783.0  Sea Disaster         MARTINIQUE
# 10          6142    1780.08.08  1780.0    Unprovoked                USA
# 11          6143    1779.00.00  1779.0    Unprovoked                USA
# 12          6144  1776.00.00.R  1776.0    Unprovoked             GUINEA
# 13          6145  1776.00.00.b  1776.0          Boat          GREENLAND
# 14          6146  1771.07.12.R  1771.0    Unprovoked                USA
# 15          6147    1767.00.00  1767.0       Invalid             FRANCE
# 16          6148    1764.00.00  1764.0    Unprovoked              SPAIN
# 17          6149    1758.00.00  1758.0    Unprovoked  MEDITERRANEAN SEA
# 18          6150  1753.10.27.R  1753.0    Unprovoked            JAMAICA
# 19          6151    1751.07.27  1751.0    Unprovoked                USA
#
#                area                            location  \
# 0          St. Anne                                 NaN
# 1               NaN                                 NaN
# 2               NaN                 On the Thames River
# 3   New South Wales                        Port Jackson
# 4   New South Wales                       Sydney Harbor
# 5         St Helena                       Landing Place
# 6               NaN                                 NaN
# 7            Sussex                            Brighton
# 8               NaN                            Kingston
# 9               NaN  Foundering of the privateer Holker
# 10          Florida   Pensacola Harbor, Escambia County
# 11           Hawaii                      Maliu, Hawai'i
# 12              NaN                                 NaN
# 13              NaN                                 NaN
# 14              NaN                          Damiscotte
# 15     Côte d'Azur                           St. Tropez
# 16              NaN                  Guadalquivir River
# 17              NaN                                 NaN
# 18              NaN                     Kingston Harbor
# 19    Massachusetts                                 NaN
#
#                                              activity  \
# 0                     a corsair's boat was overturned
# 1                                   Dropped overboard
# 2                                             Fishing
# 3                                                 NaN
# 4                                             Fishing
# 5                                            Swimming
# 6                                     Washing himself
# 7                                                 NaN
# 8                                            Swimming
# 9                                                 NaN
# 10                                           Swimming
# 11                                            Surfing
# 12                                             Murder
# 13                                                NaN
# 14                                            Fishing
# 15                                            Bathing
# 16                                           Swimming
# 17  Fell overboard from a frigate & was swallowed ...
# 18                                     Fell overboard
# 19                                           Swimming
#
#                                 name sex_    age   time  \
# 0                                NaN    F    NaN    NaN
# 1                              child  NaN    NaN    NaN
# 2                               male    M    NaN    NaN
# 3   female, an Australian aboriginal    F    NaN    NaN
# 4                               boat  NaN    NaN    NaN
# 5             Private Isaac Hicksled    M    NaN    NaN
# 6    a sailor from the York Merchant    M    NaN    NaN
# 7                                NaN    M    NaN    NaN
# 8                       Richard Page    M    NaN  22h00
# 9                                NaN    M    NaN  06h00
# 10                      Joseph Feron    M    NaN    NaN
# 11                  Nu'u-anu-pa'a hu    M  young    NaN
# 12                     African slave    M    NaN    NaN
# 13           Occupants of skin boats  NaN    NaN    NaN
# 14                              male    M    NaN    NaN
# 15                   Samuel Matthews    M    NaN    NaN
# 16                              male    M    NaN    NaN
# 17                            sailor    M    NaN    NaN
# 18                              male    M    NaN    NaN
# 19                              male    M    NaN    NaN
#
#                                              species_  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                        Tiger shark?
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                       White sharks
# 14                                                NaN
# 15            Description of shark does not ring true
# 16                                                NaN
# 17  "The fish was harpooned, dried, and presented ...
# 18                                                NaN
# 19                                                NaN
#
#                                                  href  unnamed:_0_y  \
# 0   http://sharkattackfile.net/spreadsheets/pdf_di...          6116
# 1   http://sharkattackfile.net/spreadsheets/pdf_di...          6117
# 2   http://sharkattackfile.net/spreadsheets/pdf_di...          6118
# 3   http://sharkattackfile.net/spreadsheets/pdf_di...          6119
# 4   http://sharkattackfile.net/spreadsheets/pdf_di...          6120
# 5   http://sharkattackfile.net/spreadsheets/pdf_di...          6121
# 6   http://sharkattackfile.net/spreadsheets/pdf_di...          6122
# 7   http://sharkattackfile.net/spreadsheets/pdf_di...          6123
# 8   http://sharkattackfile.net/spreadsheets/pdf_di...          6124
# 9   http://sharkattackfile.net/spreadsheets/pdf_di...          6125
# 10  http://sharkattackfile.net/spreadsheets/pdf_di...          6126
# 11  http://sharkattackfile.net/spreadsheets/pdf_di...          6127
# 12  http://sharkattackfile.net/spreadsheets/pdf_di...          6128
# 13  http://sharkattackfile.net/spreadsheets/pdf_di...          6129
# 14  http://sharkattackfile.net/spreadsheets/pdf_di...          6130
# 15  http://sharkattackfile.net/spreadsheets/pdf_di...          6131
# 16  http://sharkattackfile.net/spreadsheets/pdf_di...          6132
# 17  http://sharkattackfile.net/spreadsheets/pdf_di...          6133
# 18  http://sharkattackfile.net/spreadsheets/pdf_di...          6134
# 19  http://sharkattackfile.net/spreadsheets/pdf_di...          6135
#
#    fatal_(y/n)                                            injury  \
# 0            Y          FATAL, all onboard were killed by sharks
# 1            Y                                             FATAL
# 2            Y                          FATAL, PROVOKED INCIDENT
# 3            Y                            FATAL, "bitten in two"
# 4            N  No injury to occupants, shark bit oar and rudder
# 5            Y                                             FATAL
# 6            Y                                             FATAL
# 7            Y                Human remains recovered from shark
# 8            Y                                               NaN
# 9            Y             Many of the crew were taken by sharks
# 10           Y                                             FATAL
# 11           Y                        FATAL, buttock lacerated
# 12           Y                                             FATAL
# 13           Y                                             FATAL
# 14           Y                                             FATAL
# 15         NaN                          Lacerations to arm & leg
# 16           Y                                             FATAL
# 17           N  "He was taken up alive and but little injured."
# 18           Y                                             FATAL
# 19           Y                                             FATAL
#
#                     date
# 0                   1800
# 1   Reported May-28-1797
# 2            12-Sep-1792
# 3                   1791
# 4            10-May-1788
# 5            05-Jul-1787
# 6   Reported 10-Aug-1786
# 7   Reported 26-Sep-1785
# 8            12-Dec-1784
# 9            02-Mar-1783
# 10           08-Aug-1780
# 11                  1779
# 12         Reported 1776
# 13                  1776
# 14  Reported 12-Jul-1771
# 15                  1767
# 16                  1764
# 17                  1758
# 18  Reported 27-Oct-1753
# 19           27-Jul-1751

# %% [markdown]
# EJERCICIO 1: Cread una columna nueva y una función que nos de el mes donde ocurrió el ataque.
# Tened en cuenta que no todas las filas tienen la misma estructura y que puede que no haya la información de mes.
# En ese caso devolved un nulo (NaN).

# %%
df_copia = df.copy()

# %%
df_copia
# Out:
#       unnamed:_0_x   case_number    year          type     country  \
# 0             6132    1800.00.00  1800.0    Unprovoked  SEYCHELLES
# 1             6133  1797.05.28.R  1797.0    Unprovoked         NaN
# 2             6134    1792.09.12  1792.0      Provoked     ENGLAND
# 3             6135    1791.00.00  1791.0    Unprovoked   AUSTRALIA
# 4             6136    1788.05.10  1788.0          Boat   AUSTRALIA
# ...            ...           ...     ...           ...         ...
# 6279          6127  1804.02.26.R  1804.0          Boat   AUSTRALIA
# 6280          6128    1803.05.17  1803.0  Sea Disaster         USA
# 6281          6129    1803.03.00  1803.0    Unprovoked   AUSTRALIA
# 6282          6130  1802.04.13.R  1802.0    Unprovoked       INDIA
# 6283          6131  1801.12.18.R  1801.0      Provoked         NaN
#
#                    area                          location  \
# 0              St. Anne                               NaN
# 1                   NaN                               NaN
# 2                   NaN               On the Thames River
# 3       New South Wales                      Port Jackson
# 4       New South Wales                     Sydney Harbor
# ...                 ...                               ...
# 6279    New South Wales    Georges Head, off Port Jackson
# 6280     South Carolina                    Off Charleston
# 6281  Western Australia  Hamelin Harbour, at Faure Island
# 6282                NaN                               NaN
# 6283                NaN                               NaN
#
#                              activity                              name sex_  \
# 0     a corsair's boat was overturned                               NaN    F
# 1                   Dropped overboard                             child  NaN
# 2                             Fishing                              male    M
# 3                                 NaN  female, an Australian aboriginal    F
# 4                             Fishing                              boat  NaN
# ...                               ...                               ...  ...
# 6279                              NaN                              boat  NaN
# 6280                              NaN                     Captain Jones    M
# 6281                              NaN   M. Lefevre & a sailor (rescuer)    M
# 6282                              NaN                               NaN  NaN
# 6283  Standing on landed shark's tail                  Stephen Pettigew    N
#
#       age time   species_                                               href  \
# 0     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...   ...  ...        ...                                                ...
# 6279  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6280  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6281  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6282  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6283  NaN  NaN  12' shark  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#       unnamed:_0_y fatal_(y/n)  \
# 0             6116           Y
# 1             6117           Y
# 2             6118           Y
# 3             6119           Y
# 4             6120           N
# ...            ...         ...
# 6279          6111           N
# 6280          6112           N
# 6281          6113           N
# 6282          6114           Y
# 6283          6115           Y
#
#                                                  injury                  date
# 0              FATAL, all onboard were killed by sharks                  1800
# 1                                                 FATAL  Reported May-28-1797
# 2                              FATAL, PROVOKED INCIDENT           12-Sep-1792
# 3                                FATAL, "bitten in two"                  1791
# 4      No injury to occupants, shark bit oar and rudder           10-May-1788
# ...                                                 ...                   ...
# 6279                             No injury to occupants  Reported 26-Feb-1804
# 6280                                          No injury           May-17-1803
# 6281  Shark knocked him down & tore clothing of the ...              Mar-1803
# 6282                                              FATAL  Reported Apr-13-1802
# 6283                           FATAL, PROVOKED INCIDENT  Reported 18-Dec-1801
#
# [6284 rows x 18 columns]

# %%
def sacar_mes(x):
    try:
        return re.findall('([A-Z]{1}[a-z]{2})\-',x)[0]
    except:

        return np.nan

# %%
df_copia["mes"] = df_copia["date"].apply(sacar_mes)

# %%
df_copia.head()
# Out:
#    unnamed:_0_x   case_number    year        type     country  \
# 0          6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES
# 1          6133  1797.05.28.R  1797.0  Unprovoked         NaN
# 2          6134    1792.09.12  1792.0    Provoked     ENGLAND
# 3          6135    1791.00.00  1791.0  Unprovoked   AUSTRALIA
# 4          6136    1788.05.10  1788.0        Boat   AUSTRALIA
#
#               area             location                         activity  \
# 0         St. Anne                  NaN  a corsair's boat was overturned
# 1              NaN                  NaN                Dropped overboard
# 2              NaN  On the Thames River                          Fishing
# 3  New South Wales         Port Jackson                              NaN
# 4  New South Wales        Sydney Harbor                          Fishing
#
#                                name sex_  age time species_  \
# 0                               NaN    F  NaN  NaN      NaN
# 1                             child  NaN  NaN  NaN      NaN
# 2                              male    M  NaN  NaN      NaN
# 3  female, an Australian aboriginal    F  NaN  NaN      NaN
# 4                              boat  NaN  NaN  NaN      NaN
#
#                                                 href  unnamed:_0_y  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6116
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6117
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6118
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6119
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6120
#
#   fatal_(y/n)                                            injury  \
# 0           Y          FATAL, all onboard were killed by sharks
# 1           Y                                             FATAL
# 2           Y                          FATAL, PROVOKED INCIDENT
# 3           Y                            FATAL, "bitten in two"
# 4           N  No injury to occupants, shark bit oar and rudder
#
#                    date  mes
# 0                  1800  NaN
# 1  Reported May-28-1797  May
# 2           12-Sep-1792  Sep
# 3                  1791  NaN
# 4           10-May-1788  May

# %% [markdown]
# EJERCICIO 2: Vamos con la columna fatal_(y/n). Lo primero que tenéis que hacer es evaluar los valores únicos que hay. Esperaríamos tener solo dos valores: y y n, pero tristemente no debería ser así 😭. Cread una columna nueva y una función que devuelva únicamente y o n y que devuelva un nulo (NaN) si no se encuentra el valor.

# %%
df_copia['fatal_(y/n)'].unique()
# Out:
# array(['Y', 'N', nan, 'UNKNOWN', 'M', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
def fatal(fila):
    try:
       return re.findall(r'\b([N-zZ-a])\b', fila)[0]
    except:
        return np.nan

# %%
df_copia["fatal_"] = df_copia["fatal_(y/n)"].apply(fatal)
df_copia
# Out:
#       unnamed:_0_x   case_number    year          type     country  \
# 0             6132    1800.00.00  1800.0    Unprovoked  SEYCHELLES
# 1             6133  1797.05.28.R  1797.0    Unprovoked         NaN
# 2             6134    1792.09.12  1792.0      Provoked     ENGLAND
# 3             6135    1791.00.00  1791.0    Unprovoked   AUSTRALIA
# 4             6136    1788.05.10  1788.0          Boat   AUSTRALIA
# ...            ...           ...     ...           ...         ...
# 6279          6127  1804.02.26.R  1804.0          Boat   AUSTRALIA
# 6280          6128    1803.05.17  1803.0  Sea Disaster         USA
# 6281          6129    1803.03.00  1803.0    Unprovoked   AUSTRALIA
# 6282          6130  1802.04.13.R  1802.0    Unprovoked       INDIA
# 6283          6131  1801.12.18.R  1801.0      Provoked         NaN
#
#                    area                          location  \
# 0              St. Anne                               NaN
# 1                   NaN                               NaN
# 2                   NaN               On the Thames River
# 3       New South Wales                      Port Jackson
# 4       New South Wales                     Sydney Harbor
# ...                 ...                               ...
# 6279    New South Wales    Georges Head, off Port Jackson
# 6280     South Carolina                    Off Charleston
# 6281  Western Australia  Hamelin Harbour, at Faure Island
# 6282                NaN                               NaN
# 6283                NaN                               NaN
#
#                              activity                              name sex_  \
# 0     a corsair's boat was overturned                               NaN    F
# 1                   Dropped overboard                             child  NaN
# 2                             Fishing                              male    M
# 3                                 NaN  female, an Australian aboriginal    F
# 4                             Fishing                              boat  NaN
# ...                               ...                               ...  ...
# 6279                              NaN                              boat  NaN
# 6280                              NaN                     Captain Jones    M
# 6281                              NaN   M. Lefevre & a sailor (rescuer)    M
# 6282                              NaN                               NaN  NaN
# 6283  Standing on landed shark's tail                  Stephen Pettigew    N
#
#       age time   species_                                               href  \
# 0     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...   ...  ...        ...                                                ...
# 6279  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6280  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6281  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6282  NaN  NaN        NaN  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6283  NaN  NaN  12' shark  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#       unnamed:_0_y fatal_(y/n)  \
# 0             6116           Y
# 1             6117           Y
# 2             6118           Y
# 3             6119           Y
# 4             6120           N
# ...            ...         ...
# 6279          6111           N
# 6280          6112           N
# 6281          6113           N
# 6282          6114           Y
# 6283          6115           Y
#
#                                                  injury                  date  \
# 0              FATAL, all onboard were killed by sharks                  1800
# 1                                                 FATAL  Reported May-28-1797
# 2                              FATAL, PROVOKED INCIDENT           12-Sep-1792
# 3                                FATAL, "bitten in two"                  1791
# 4      No injury to occupants, shark bit oar and rudder           10-May-1788
# ...                                                 ...                   ...
# 6279                             No injury to occupants  Reported 26-Feb-1804
# 6280                                          No injury           May-17-1803
# 6281  Shark knocked him down & tore clothing of the ...              Mar-1803
# 6282                                              FATAL  Reported Apr-13-1802
# 6283                           FATAL, PROVOKED INCIDENT  Reported 18-Dec-1801
#
#       mes fatal_
# 0     NaN      Y
# 1     May      Y
# 2     Sep      Y
# 3     NaN      Y
# 4     May      N
# ...   ...    ...
# 6279  Feb      N
# 6280  May      N
# 6281  Mar      N
# 6282  Apr      Y
# 6283  Dec      Y
#
# [6284 rows x 20 columns]

# %%
df_copia['fatal_'].unique()
# Out:
# array(['Y', 'N', nan, 'y'], dtype=object)

# %%
df_copia['fatal_'].replace(to_replace = ['Y', 'N'], value = ['y', 'n'], inplace=True)

# %%
df_copia['fatal_'].unique()
# Out:
# array(['y', 'n', nan], dtype=object)

# %% [markdown]
# EJERCICIO 3: Seguid la misma lógica que en el ejercicio anterior pero con la columna sex. Pero en este caso vamos a incluir un retito más: En este caso querremos tener dos valores únicos F y M. De nuevo en la columna hay otros carácteres raros como 'M ', 'lli', 'N', '.'. En esos casos, queremos que se reemplacen por M o F de forma aleatoria (tendréis que usar la librería random). En caso de que sea nulo, que la función devuelva nulo (np.nan).

# %%
sex = df_copia['sex_'].unique()
type(sex[1])
# Out:
# float

# %%
sex = list(sex)
sex
# Out:
# ['F', nan, 'M', 'M ', 'lli', 'N', '.']

# %%
val_sexos = ['M', 'F']

# %%
def sexo(x):

    try:
        np.isnan(x) == True
        return np.nan
   
    except:

        try:
            return re.findall(r'[F]|[f]|[M]|[m]', x)[0]
            
        except:

                return np.random.choice(val_sexos, size=1)[0]

# %%
df_copia["sex2"] = df_copia["sex_"].apply(sexo)

# %%
df_copia['sex2'].unique()
# Out:
# array(['F', nan, 'M'], dtype=object)

# %%
df_copia.sample(5)
# Out:
#       unnamed:_0_x case_number    year          type               country  \
# 1134           968  2010.11.19  2010.0      Provoked                   USA
# 2867          2705  1988.11.07  1988.0  Sea Disaster             AUSTRALIA
# 4889          4731  1941.12.07  1941.0  Sea Disaster  SOUTH ATLANTIC OCEAN
# 4944          4786  1939.11.09  1939.0       Boating             AUSTRALIA
# 4585          4427  1951.11.29  1951.0    Unprovoked          SOUTH AFRICA
#
#                  area                              location  \
# 1134    Palmyra Atoll                                   NaN
# 2867       Queensland  Off North Keppel Island, off Yeppoon
# 4889              NaN                                   NaN
# 4944  New South Wales                            Wollongong
# 4585    KwaZulu-Natal                   South Beach, Durban
#
#                                                activity           name sex_  \
# 1134                                         Snorkeling   Kydd Pollock    M
# 2867  The Christie V sank on 11/6/1988, survivors we...  Cedric Coucom    M
# 4889  Torpedoed & burning British  light cruiser wit...            NaN  NaN
# 4944                                                NaN   another boat  NaN
# 4585                                           Swimming    Harold Tait    M
#
#       ...       time                                           species_  \
# 1134  ...      13h30                                                NaN
# 2867  ...  Nightfall                                                NaN
# 4889  ...        NaN  Reportedly: oceanic whitetip sharks, blue shar...
# 4944  ...        NaN                                                NaN
# 4585  ...      13h00                           White shark, 1.8 m [6']
#
#                                                    href unnamed:_0_y  \
# 1134  http://sharkattackfile.net/spreadsheets/pdf_di...          965
# 2867  http://sharkattackfile.net/spreadsheets/pdf_di...         2698
# 4889  http://sharkattackfile.net/spreadsheets/pdf_di...         4720
# 4944  http://sharkattackfile.net/spreadsheets/pdf_di...         4775
# 4585  http://sharkattackfile.net/spreadsheets/pdf_di...         4416
#
#       fatal_(y/n)                                             injury  \
# 1134            N      Head bitten by netted shark PROVOKED INCIDENT
# 2867            Y                                              FATAL
# 4889            Y  Only 170 survived, many of the crew were said ...
# 4944      UNKNOWN                                         No details
# 4585            N                            Thigh bruised & abraded
#
#              date  mes fatal_ sex2
# 1134  19-Nov-2010  Nov      n    M
# 2867  07-Nov-1988  Nov      y    M
# 4889  07-Dec-1941  Dec      y  NaN
# 4944  09-Nov-1939  Nov    NaN  NaN
# 4585  29-Nov-1951  Nov      n    M
#
# [5 rows x 21 columns]

# %% [markdown]
# EJERCICIO 4: Una vez que hayáis terminado eliminad las columnas originales conservando las nuevas.

# %%
df_copia.drop(['sex_','fatal_(y/n)'], axis = 1, inplace=True)

# %% [markdown]
# EJERCICIO 5: Guardad el dataframe en un csv que usaremos más adelante

# %%
df_copia.to_csv('attack_limpio.csv')
