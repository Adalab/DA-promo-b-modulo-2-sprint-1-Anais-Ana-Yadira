# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# El objetivo de hoy, mejorar algunas de las gráficas que hicimos en el ejericio de pair programming de ayer y crear algunas nuevas aprovechando que tenemos algunas columnas nuevas en dataframe

# %%
df = pd.read_csv("attack_pair.csv")

# %% [markdown]
# EJERCICIO 1: Ayer creamos un par de gráficas para USA y España, donde visualizamos el número de ataques en cada país a lo largo de los años y el tipo de los ataques. Hoy tendréis que hacer dos gráficas con subplots:
#
# - En la primera debéis mostrar los tipos ataques en USA y España, cada subplot corresponderá a un país. Debéis:
# - Poner nombre a los ejes de cada uno de los subplots
# - Poner un títulos a cada uno de los subplots
# - Poner el color de las líneas en negro.
# - Establecer el tamaño de la gráfica a 15 x 5
# - Ponerle marcadores a las gráficas
# - No incluir leyenda
#
# En la segunda debéis mostrar los ataques por año para cada uno de los países.
# - De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica.
# - En este caso el subplot deberá tener dos filas y una columna
# - No incluir leyenda
# - Cambiar el color de las barras

# %%
datos_usa = df[(df['country']=='USA') & (df['year'] > 2000)]
ataques_años_usa = datos_usa.groupby('year')['case_number'].count()
ataques_años_usa
# Out:
# year
# 2001.0    58
# 2002.0    49
# 2003.0    57
# 2004.0    35
# 2005.0    52
# 2006.0    54
# 2007.0    66
# 2008.0    60
# 2009.0    41
# 2010.0    40
# 2011.0    48
# 2012.0    63
# 2013.0    59
# 2014.0    65
# 2015.0    73
# 2016.0    64
# 2017.0    65
# 2018.0    10
# Name: case_number, dtype: int64

# %%
datos_spain = df[(df['country']=='SPAIN') & (df['year'] > 2000)]
ataques_años_spain = datos_spain.groupby('year')['case_number'].count()
ataques_años_spain
# Out:
# year
# 2006.0    1
# 2009.0    1
# 2010.0    1
# 2013.0    1
# 2014.0    4
# 2015.0    2
# 2016.0    2
# 2017.0    4
# Name: case_number, dtype: int64

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize =(15,5))


ax[0].plot(ataques_años_usa.index, ataques_años_usa.values, marker='X', color = 'black')

ax[0].set_title('Gráfica lineal de la cantidad de ataques por año en USA')
ax[0].set_xlabel('Año')
ax[0].set_ylabel('Cantidad de Ataques')

ax[1].plot(ataques_años_spain.index, ataques_años_spain.values, marker='p', color='black')

ax[1].set_title('Gráfica lineal de la cantidad de ataques por año en España')
ax[1].set_xlabel('Año')
ax[1].set_ylabel('Cantidad de Ataques')

plt.savefig('visualización-II/ataques_año.jpeg')


plt.show()

# %%
ataques_tipo_usa = datos_usa.groupby('type')['case_number'].count()
ataques_tipo_usa
# Out:
# type
# Boat              3
# Boating          32
# Invalid          65
# Provoked         60
# Sea Disaster      2
# Unprovoked      797
# Name: case_number, dtype: int64

# %%
ataques_tipo_spain = datos_spain.groupby('type')['case_number'].count()
ataques_tipo_spain
# Out:
# type
# Invalid       5
# Provoked      2
# Unprovoked    9
# Name: case_number, dtype: int64

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize =(10,15))


ax[0].bar(ataques_tipo_usa.index, ataques_tipo_usa.values, color = 'crimson')

ax[0].set_title('Gráfica de barras de la cantidad de ataques por tipo de ataque en USA')
ax[0].set_xlabel('Tipo de ataque')
ax[0].set_ylabel('Cantidad de Ataques')

ax[1].bar(ataques_tipo_spain.index, ataques_tipo_spain.values, color='mediumpurple')

ax[1].set_title('Gráfica de barras de la cantidad de ataques por tipo de ataque en España')
ax[1].set_xlabel('Tipo de ataque')
ax[1].set_ylabel('Cantidad de Ataques')

plt.savefig('visualización-II/ataquestipo.jpeg')

# %% [markdown]
# EJERCICIO 2: Cread un único gráfico donde juntéis las gráficas de los tipos de ataques en una sola. Debéis:
# - Poner leyenda a la gráfica
# - Cada línea debe ir en un color
# - Ponerle nombre a los ejes y a la gráfica.
# - Poner marcadores a las lineas.

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize =(20,20))


ax[0][0].plot(ataques_años_usa.index, ataques_años_usa.values, marker='X', color = 'red')

ax[0][0].set_title('Gráfica lineal de la cantidad de ataques por año en USA')
ax[0][0].set_xlabel('Año')
ax[0][0].set_ylabel('Cantidad de Ataques')

ax[0][1].plot(ataques_años_spain.index, ataques_años_spain.values, marker='p', color='blue')

ax[0][1].set_title('Gráfica lineal de la cantidad de ataques por año en España')
ax[0][1].set_xlabel('Año')
ax[0][1].set_ylabel('Cantidad de Ataques')


ax[1][0].bar(ataques_tipo_usa.index, ataques_tipo_usa.values, color = 'crimson')

ax[1][0].set_title('Gráfica de barras de la cantidad de ataques por tipo de ataque en USA')
ax[1][0].set_xlabel('Tipo de ataque')
ax[1][0].set_ylabel('Cantidad de Ataques')

ax[1][1].bar(ataques_tipo_spain.index, ataques_tipo_spain.values, color='mediumpurple')

ax[1][1].set_title('Gráfica de barras de la cantidad de ataques por tipo de ataque en España')
ax[1][1].set_xlabel('Tipo de ataque')
ax[1][1].set_ylabel('Cantidad de Ataques')

plt.savefig('visualización-II/ataques4.jpeg')

# %% [markdown]
# EJERCICIO 3: Guardad las figuras creadas en cada caso. Podéis usar el formato que queráis. Guarda todas las fotos en una carpeta llamada Visualizacion-II.

# %% [markdown]
# Hecho al final de cada gráfica
