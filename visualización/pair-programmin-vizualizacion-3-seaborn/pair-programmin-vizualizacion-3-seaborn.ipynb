# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("attack_pair.csv")

# %%
df.head()
# Out:
#   case_number  unnamed:_0    year        type    country             area  \
# 0  2018.06.25           0  2018.0     Boating        USA       California
# 1  2018.06.18           1  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09           2  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08           3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04           4  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...

# %%
df.columns
# Out:
# Index(['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'href'],
#       dtype='object')

# %%
df["activity"].unique().size
# Out:
# 1485

# %% [markdown]
# EJERCICIO 1
#
# Usando la librería seaborn, crea una gráfica de barras que muestre el número de personas que han hecho cada actividad en cada año. Hacedlo solo desde el 2015. Os podrá salir una gráfica un poco fea, no os preocupeis, es lo que esperamos.

# %%
df.groupby(['activity','year']).size().reset_index()
# Out:
#                                                activity    year  0
# 0                                                        1900.0  1
# 1                                                        1993.0  1
# 2      a canoe was pursuing a schooner that had forc...  1892.0  1
# 3                                       "Boat accident"  1895.0  1
# 4     "Climbing up to ship after repairing the stern...  1958.0  1
# ...                                                 ...     ... ..
# 2936           ship William Penn grounded & broke apart  1855.0  1
# 2937  ship torpedoed 400 miles off the African coas....  1943.0  1
# 2938                                         small boat  1893.0  1
# 2939        wreck of the State Oil Company ship Permina  1966.0  1
# 2940                                  yachting accident  1884.0  1
#
# [2941 rows x 3 columns]

# %%
df_2015= df[df["year"]>=2015]
df_2015
# Out:
#     case_number  unnamed:_0    year        type       country  \
# 0    2018.06.25           0  2018.0     Boating           USA
# 1    2018.06.18           1  2018.0  Unprovoked           USA
# 2    2018.06.09           2  2018.0     Invalid           USA
# 3    2018.06.08           3  2018.0  Unprovoked     AUSTRALIA
# 4    2018.06.04           4  2018.0    Provoked        MEXICO
# ..          ...         ...     ...         ...           ...
# 457  2015.01.16         458  2015.0  Unprovoked     AUSTRALIA
# 458  2015.01.08         459  2015.0     Invalid           USA
# 459  2015.01.06         460  2015.0  Unprovoked       BAHAMAS
# 460  2015.01.03         461  2015.0  Unprovoked  SOUTH AFRICA
# 461  2015.01.01         462  2015.0  Unprovoked           USA
#
#                       area                            location  \
# 0               California         Oceanside, San Diego County
# 1                  Georgia      St. Simon Island, Glynn County
# ...

# %%
df_2015["activity"].unique().size
# Out:
# 84

# %%
plt.figure(figsize =(8,4))
fig = sns.histplot(x='activity', data = df_2015, bins=84)
fig.set(xlabel='activity', ylabel = 'cantidad de personas por activity')
fig.set_title('Gráfica de Barras de cantidad de personas por actividad' )
plt.show()

# %% [markdown]
# EJERCICIO 2
#
# Usando la librería seaborn, crea una gráfica de barras que muestre el número de ataques que han ocurrido cada año en función del sexo. Hacedlo solo desde el 2015.

# %%
plt.figure(figsize =(8,4))
fig = sns.histplot(x='year', data = df_2015,hue = 'sex_')
fig.set(xlabel='Año de los ataques', ylabel = 'Cantidad de ataques por sexo')
fig.set_title('Gráfica de barras del número de ataques por año y sexo')
plt.show()

# %% [markdown]
# EJERCICIO 3
#
# ¿Cuántos ataques hubo por año? Seleccionad solo desde el año 1500.

# %%
df_1500= df[df["year"]>=1500]
df_1500
# Out:
#        case_number  unnamed:_0    year          type    country  \
# 0       2018.06.25           0  2018.0       Boating        USA
# 1       2018.06.18           1  2018.0    Unprovoked        USA
# 2       2018.06.09           2  2018.0       Invalid        USA
# 3       2018.06.08           3  2018.0    Unprovoked  AUSTRALIA
# 4       2018.06.04           4  2018.0      Provoked     MEXICO
# ...            ...         ...     ...           ...        ...
# 6109  1804.02.26.R        6127  1804.0          Boat  AUSTRALIA
# 6110    1803.05.17        6128  1803.0  Sea Disaster        USA
# 6111    1803.03.00        6129  1803.0    Unprovoked  AUSTRALIA
# 6112  1802.04.13.R        6130  1802.0    Unprovoked      INDIA
# 6113  1801.12.18.R        6131  1801.0      Provoked        NaN
#
#                    area                          location  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# ...

# %%
plt.figure(figsize =(8,4))
fig = sns.histplot(x='year', data = df_2015,hue = 'sex_')
fig.set(xlabel='Año de los ataques', ylabel = 'Cantidad de ataques por sexo')
fig.set_title('Gráfica de barras del número de ataques por año y sexo')
plt.show()

# %% [markdown]
# EJERCICIO 4
#
# Seleccionad solo los registros de USA, AUSTRALIA y SOUTH AFRICA. Muestra el número de ataques por país y año desde el año 1900.

# %%
df_paises= df[(df['country']=='USA') | (df['country']== 'AUSTRALIA') | (df['country']=='SOUTH AFRICA')]
df_paises
# Out:
#        case_number  unnamed:_0    year          type    country  \
# 0       2018.06.25           0  2018.0       Boating        USA
# 1       2018.06.18           1  2018.0    Unprovoked        USA
# 2       2018.06.09           2  2018.0       Invalid        USA
# 3       2018.06.08           3  2018.0    Unprovoked  AUSTRALIA
# 5     2018.06.03.b           5  2018.0    Unprovoked  AUSTRALIA
# ...            ...         ...     ...           ...        ...
# 6107    1806.04.24        6125  1896.0  Sea Disaster        USA
# 6108    1805.09.00        6126  1805.0       Invalid        USA
# 6109  1804.02.26.R        6127  1804.0          Boat  AUSTRALIA
# 6110    1803.05.17        6128  1803.0  Sea Disaster        USA
# 6111    1803.03.00        6129  1803.0    Unprovoked  AUSTRALIA
#
#                    area                          location      activity  \
# 0            California       Oceanside, San Diego County      Paddling
# ...

# %%
df_ej4= df_paises[df_paises["year"]>=1900]
df_ej4
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 1       2018.06.18           1  2018.0  Unprovoked           USA
# 2       2018.06.09           2  2018.0     Invalid           USA
# 3       2018.06.08           3  2018.0  Unprovoked     AUSTRALIA
# 5     2018.06.03.b           5  2018.0  Unprovoked     AUSTRALIA
# ...            ...         ...     ...         ...           ...
# 5542    1900.07.14        5559  1900.0     Invalid           USA
# 5543    1900.07.00        5560  1900.0    Provoked           USA
# 5544    1900.01.28        5561  1900.0  Unprovoked     AUSTRALIA
# 5545  1900.00.00.b        5562  1900.0  Unprovoked           USA
# 5546  1900.00.00.a        5563  1900.0  Unprovoked  SOUTH AFRICA
#
#                        area  \
# 0                California
# 1                   Georgia
# 2                    Hawaii
# 3           New South Wales
# 5           New South Wales
# ...

# %%
plt.figure(figsize =(8,4))
fig = sns.histplot(x='year', data = df_ej4,hue = 'country')
fig.set(xlabel='Año de los ataques', ylabel = 'Cantidad de ataques en USA, Australia y South Africa')
fig.set_title('Gráfica de barras la cantidad de ataques en USA, Australia y South Africa')
plt.show()

# %% [markdown]
# EJERCICIO 5
#
# Realizad un boxplot donde se muestre los principales estadísticos del número de ataques por país.

# %%
attack_pais = df.groupby(['country'])['case_number'].count()
attack_pais
# Out:
# country
#  PHILIPPINES          1
#  TONGA                3
# ADMIRALTY ISLANDS     1
# AFRICA                1
# ALGERIA               1
#                      ..
# VIETNAM              13
# WEST INDIES           2
# WESTERN SAMOA         1
# YEMEN                 2
# YEMEN                 7
# Name: case_number, Length: 201, dtype: int64

# %%
# Boxplot por vertical, por isla
plt.figure(figsize =(8,4))
fig = sns.boxplot(x= attack_pais.index, y = attack_pais.values, data = attack_pais)
fig.set(xlabel='Isla', ylabel= 'Longitud de la aleta en mm')
fig.set_title('Boxplot de la longitud de la aleta en mm por isla')
plt.show()

# %%
# Boxplot por vertical, por isla
plt.figure(figsize =(8,4))
fig = sns.boxplot(x= 'island', y ='body_mass_g',hue= 'species', data = df_penguin)
fig.set(xlabel='Isla', ylabel= 'Longitud de la aleta en mm por isla y sexo' )
fig.set_title('Boxplot de la longitud de la aleta')
plt.show()
